# %% [markdown]
# # HW 16

# %% [markdown]
# ## Examples

# %% [markdown]
# ## Task 1

# %%
from hw_16 import DNASequence, RNASequence, AminoAcidSequence, filter_fastq

# %%
dna = DNASequence('AATT')

# %%
dna.check_alphabet()
# Out:
# True

# %%
print(dna)
# Out:
# Sequence: AATT
# Sequence length: 4

# %%
dna

# %%
print(dna.reverse())
# Out:
# Sequence: TTAA
# Sequence length: 4

# %%
print(dna.transcribe())
# Out:
# Sequence: AAUU
# Sequence length: 4

# %%
print(dna.reverse_complement())
# Out:
# Sequence: AATT
# Sequence length: 4

# %%
print(dna.complement())
# Out:
# Sequence: TTAA
# Sequence length: 4

# %%
belok = AminoAcidSequence('AAMMPP')

# %%
belok.get_aa_abundance()
# Out:
# Aminoacid abundances:
#  {'A': 2, 'M': 2, 'P': 2}

# %% [markdown]
# ## Task 2

# %%
filter_fastq(file_name = 'data/example_fastq.fastq', 
                    length_bounds = [10, 20],
                    gc_bounds = [30, 80],
                    quality_threshold = 37)

# %% [markdown]
# Content of output file:
#
#
# @SRX079804:1:SRR292678:1:1101:1103499:1103499 1:N:0:1 BH:failed
# GACCTTCAAGCCA
# +
# @GGGGGGGGGGGG
